# %%
# The code was removed by Watson Studio for sharing.

# %%
jcampaign =pd.read_excel(streaming_body_1)
jcampaign.head()
# Out:
#    Prefix First Name   MI Last Name Suffix                     Address  \
# 0     NaN     Morgan  NaN   Abraham    NaN        24443 N. 119th Place
# 1     NaN     Hilary    A      Beck    NaN    711 N EVERGREEN RD #3030
# 2     NaN    Douglas    A      Behm    NaN         1724 E Monona Drive
# 3     NaN      Marie  NaN    Benson    NaN      10891 E. Oakwood Drive
# 4     NaN    Patrick    J      Berg    NaN  17189 S Painted Vistas Way
#
#          City State    Zip                          Employer  \
# 0  Scottsdale    AZ  85255                           student
# 1        MESA    AZ  85201                        LCOR, Inc
# 2     Phoenix    AZ  85024            Union Pacific Railroad
# 3      Tucson    AZ  85749                            TVECP
# 4        Vail    AZ  85641  US Customs and BOrder Protection
#
#                        Occupation  Amount Batch Deposit Date  \
# 0                         student    25.0         2011-09-26
# ...

# %%
johnson_campaign=jcampaign[['First Name', 'MI', 'Last Name', 'City', 'State', 'Occupation', 'TotalAllSubmission']].copy()
johnson_campaign.head()
# Out:
#   First Name   MI Last Name        City State                      Occupation  \
# 0     Morgan  NaN   Abraham  Scottsdale    AZ                         student
# 1     Hilary    A      Beck        MESA    AZ                  Leasing Agent
# 2    Douglas    A      Behm     Phoenix    AZ                          welder
# 3      Marie  NaN    Benson      Tucson    AZ  Director after school program
# 4    Patrick    J      Berg        Vail    AZ         Law enforcement officer
#
#    TotalAllSubmission
# 0                25.0
# 1               100.0
# 2                25.0
# 3                25.0
# 4               100.0

# %%
final_johnson_campaign=johnson_campaign.drop_duplicates(subset ="First Name", 
                     keep = 'first') 
final_johnson_campaign.head()
# Out:
#   First Name   MI Last Name        City State                      Occupation  \
# 0     Morgan  NaN   Abraham  Scottsdale    AZ                         student
# 1     Hilary    A      Beck        MESA    AZ                  Leasing Agent
# 2    Douglas    A      Behm     Phoenix    AZ                          welder
# 3      Marie  NaN    Benson      Tucson    AZ  Director after school program
# 4    Patrick    J      Berg        Vail    AZ         Law enforcement officer
#
#    TotalAllSubmission
# 0                25.0
# 1               100.0
# 2                25.0
# 3                25.0
# 4               100.0

# %%
final_johnson_campaign['TotalAllSubmission'].plot(kind="hist")
plt.xlabel("Histogram for the amount donated to jhonson for campaign vs number of people")
plt.show()

# %%
jAmountVsOccupation=final_johnson_campaign[['Occupation','TotalAllSubmission']]
jAmountVsOccupationPlot=jAmountVsOccupation.pivot_table(index=["Occupation"])
jAmountVsOccupationPlot.head()
#f, ax = plt.subplots(figsize=(7, 3))
jAmountVsOccupationPlot.plot(figsize=(30,1))
plt.show()

# %%
#state=final_johnson_campaign[['State']]
amt=final_johnson_campaign[['TotalAllSubmission']]
#fig, ax = plt.subplots()
#ax.plot(state, amt, label="state check")
print (type(final_johnson_campaign[['TotalAllSubmission']]))
convert_dict = {'TotalAllSubmission': int, 
                'State': str
               } 
  
final_johnson_campaign = final_johnson_campaign.astype(convert_dict) 
print(final_johnson_campaign.dtypes) 

#ax.legend()

#plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# First Name            object
# MI                    object
# Last Name             object
# City                  object
# State                 object
# Occupation            object
# TotalAllSubmission     int64
# dtype: object

# %%
final_johnson_campaign[['TotalAllSubmission']] = final_johnson_campaign[['TotalAllSubmission']].apply(pd.to_numeric) 
df=final_johnson_campaign
print(df.dtypes)
# Out:
# First Name            object
# MI                    object
# Last Name             object
# City                  object
# State                 object
# Occupation            object
# TotalAllSubmission     int64
# dtype: object

# %%
sea.catplot(x="State", y="TotalAllSubmission", data=df);

# %%
fig_dims=(20,6)
fig, ax = plt.subplots(figsize=fig_dims)
sea.catplot(x="Occupation", y="TotalAllSubmission",ax=ax, data=df);

# %%
sea. (x="State", y="TotalAllSubmission", kind="bar", data=df);

# %%
sea.catplot(x="TotalAllSubmission", y="State",
            kind="violin", data=df);

# %%
sea.catplot(x="TotalAllSubmission", y="State",
            kind="violin", inner="stick", split=True,
            palette="pastel", data=df);

# %%
g = sea.catplot(x="TotalAllSubmission", y="State", kind="violin", inner=None, data=df)
sea.swarmplot(x="TotalAllSubmission", y="State", color="k", size=3, data=df, ax=g.ax);

# %%
fig_dims=(20,6)
fig, ax = plt.subplots(figsize=fig_dims)
sea.catplot(x="Occupation", y="TotalAllSubmission", kind="bar", ax=ax, data=df);

# %%
#fig_dims=(20,40)
#fig, ax = plt.subplots(figsize=fig_dims)
sea.catplot(x="TotalAllSubmission", y="Occupation", 
            col="State", height=20, aspect=11.7/8.26,
            kind="swarm", data=df);

# %%
sea.catplot(x="TotalAllSubmission", y="State", 
            col="Occupation", 
            kind="swarm", data=df);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-fa596ed54d61> in <module>
#       1 sea.catplot(x="TotalAllSubmission", y="State",
#       2             col="Occupation",
# ----> 3             kind="swarm", data=df);
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3750
#    3751     # Initialize the facets
# -> 3752     g = FacetGrid(**facet_kws)
#    3753
#    3754     # Draw the plot onto the facets
#
# ...
